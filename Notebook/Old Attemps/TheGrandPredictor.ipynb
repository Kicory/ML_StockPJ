# %% [markdown]
# <a href="https://colab.research.google.com/github/Kicory/ML_StockPJ/blob/master/Notebook/TheGrandPredictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0.
# 제가 train을 하고 파라미터 파일은 아마도 깃에 올리지 않을까... 생각합니다. 깃이랑 colab이랑 마운트해서 사용할 수 있는 방법이 있을까 계속 찾아봤는데 없는 것 같네요. 귀찮지만...

# %%
from google.colab import drive

drive.mount('/gdrive')
gdrive_root = '/gdrive/My Drive'
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import os

import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

# for teaching force
import random

# for CSV
import pandas as pd
import numpy as np

# for visual plot
import matplotlib.pyplot as plt

# for data
import sklearn.preprocessing as skpp
import sklearn.model_selection as skms

# for deco
from tqdm import tqdm_notebook, tnrange

#from torch.utils.data import DataLoader

# %%
torch.manual_seed(470)
torch.cuda.manual_seed(470)

# %%
device = 'cuda'

# %%
data_dir = os.path.join(gdrive_root, 'Project/Data')

# %% [markdown]
# # 시작하기
# 이 프로젝트에서는 좀 특이한 방식으로 데이터 처리를 해야 합니다. 이유는 다음과 같습니다.
#
# pytorch.nn 의 모듈을 상속받아 만든 클래스로 어떤 모델을 만들었다고 해 봅시다. 해당 모델의 desirable input dimension이 n이라고 합시다.
#
#
# *   minibatch갯수가 1일 때: n차원의 input을 넣으면 정상 작동(당연)
# *   minibatch갯수가 2이상: n + 1차원의 input을 넣음(???)
#
# pytorch가 용하게도 input의 첫 번째 원소를 minibatch의 갯수로 인식하고 input을 minibatch 수만큼 갈라서 병렬 처리를 하는 겁니다. 그러면 input은 n차원의 minibatch개 input으로 나뉘어집니다. 이게 기본 작동 원리입니다.
#
# 일반적인 방법으로 데이터를 쪼개면 이런 관례에 따라 minibatch 갯수가 첫 차원의 원소로 들어가게 됩니다. 그런데 지금 우리가 가지고 있는 데이터셋을 일반적인 방법으로 쪼갠다면 다음과 같은 모양을 하게 됩니다.
#
# *   (minibatch 수, 연속된 주식 정보 갯수, 주식 정보(5))
#
# 이걸 LSTMCell에 넣으려면 (minibatch, 주식 정보(5))로 가공해서 연속적으로 넣어야 합니다. 그 말인즉슨 0번째 차원과 1번째 원소를 뒤바꿔야 하는데 이거 엄청 비효율입니다.
#
# 따라서 데이터셋 가공에 신경을 써서
#
# *   (연속된 주식 정보 갯수, minibatch 수, 주식 정보(5))
#
# 으로 만들어야 합니다.

# %%
DATA_PATH = os.path.join(data_dir, 'KOSPI.csv')

UsingCols = [1, 2, 3, 4, 5, 6, 7, 8]
LSTMHiddenSize_1 = 16
DropoutRate = 0.5
LSTMHiddenSize_2 = 16
GradientClip = 5
batchSize = 1

GivenCnt = 12
PredictCnt = 3

# %%
UsingColsCnt = len(UsingCols)
DATA = pd.read_csv(DATA_PATH, engine='c', usecols=UsingCols)
plt.figure()
plt.plot(DATA["END"])
plt.title('Fxxxing True Data')
plt.ylabel('END Price (Won)')
plt.xlabel('Days')
plt.show()

# %%
TRAIN, TEST = skms.train_test_split(DATA, train_size=0.8, test_size=0.2, shuffle=False)
print('Train :', len(TRAIN), '\nTest :', len(TEST))
scaler = skpp.MinMaxScaler(feature_range=(-1, 1))
TRAIN = scaler.fit_transform(TRAIN.to_numpy())
TEST = scaler.fit_transform(TEST.to_numpy())
# Out:
# Train : 5098
# Test : 1275

# %%
def makeInputUnits(whole, given, predicting):
  entryCnt = whole.shape[0]
  entryDim = whole.shape[1]

  unitLen = given + predicting
  unitCnt = entryCnt - unitLen + 1

  givenEntries = np.zeros((unitCnt, given, entryDim))
  predictEntries = np.zeros((unitCnt, predicting, entryDim))

  for idx in tqdm_notebook(range(unitCnt)):
    givenEntries[idx] = whole[idx : idx + given]
    predictEntries[idx] = whole[idx + given : idx + given + predicting]
  
  return givenEntries, predictEntries

# %%
def makeBatches(givens, predicts, b_size):
  unitCnt = givens.shape[0]
  unitsLeft = unitCnt

  givenLen = givens.shape[1]
  predictLen = predicts.shape[1]

  entryDim = givens.shape[2]

  unitPointer = 0

  while unitsLeft > b_size:
    retBatchGivens = givens[unitPointer : unitPointer + b_size]
    retBatchPredicts = predicts[unitPointer : unitPointer + b_size]

    unitsLeft = unitsLeft - b_size
    unitPointer = unitPointer + 1
    
    yield retBatchGivens.swapaxes(0, 1), retBatchPredicts.swapaxes(0, 1)

# %%
G, P = makeInputUnits(TRAIN, 3, 1)
batIter = makeBatches(G, P, 2)
for bat in batIter:
  GG, PP = bat
  print(GG)
  print(PP)
  break

# %%
# # 이게 되려나???
# def getInputData(theFile, length, batchSize):
#   whole = []
#   for skipper in range(0, length, length // 5):
#     reader = pd.read_csv(theFile, sep=',', chunksize=length * batchSize, usecols=UsingCols, skiprows=skipper)
#     for chunk in reader:
#       if chunk.shape[0] != length * batchSize:
#         break;
#       whole.append(torch.Tensor(chunk.to_numpy().reshape(batchSize, length, UsingColsCnt).swapaxes(0, 1)))

#   random.shuffle(whole)
#   for idx in range(len(whole)):
#     yield whole[idx]

# %% [markdown]
# # 2. 모델 설명
#
# 예를 들어 10일간의 주식 정보를 minibatch 4 개로 해서 train 한다.
# hidden size가 32다.
# *   x.size() = [10, 4, 5]
# *   h0.size(), c0.size() = [4, 32] (근데 이건 어차피 0으로 초기화되니 굳이 설정할 필요는 없..)
# *   futureRatio = 얼마만큼을 '예측할' 그래프로 할 것인지
#  *   0.5라면 절반 만큼은 teacherForcing 100%, 절반은 teacherForcing 적게.
# *   TFRatio = 예측하는 그래프에서 teacherForcing이 일어날 확률.

# %%
class GrandPredictor(nn.Module):
  def __init__(self, hiddenSize_1=16, dropoutRate=0.2, hiddenSize_2=16):
    super(GrandPredictor, self).__init__()
    self.lstm1 = nn.LSTMCell(UsingColsCnt, hiddenSize_1)
    self.dropout = nn.Dropout(p=dropoutRate)
    self.lstm2 = nn.LSTMCell(hiddenSize_1, hiddenSize_2)
    self.FCout = nn.Linear(hiddenSize_2, UsingColsCnt)

  def forward(self, x, h=None, c=None):
    if h is None:
      h = (None, None)
    if c is None:
      c = (None, None)
    h1, h2 = h
    c1, c2 = c

    if h1 is None or c1 is None:
      h1, c1 = self.lstm1(x)
    else:
      h1, c1 = self.lstm1(x, (h1, c1))
      
    h1 = self.dropout(h1)

    if h2 is None or c2 is None:
      h2, c2 = self.lstm2(h1)
    else:
      h2, c2 = self.lstm2(h1, (h2, c2))

    prediction = self.FCout(h2)
    return prediction, (h1, h2), (c1, c2)

# %%
predictor = GrandPredictor(LSTMHiddenSize_1, DropoutRate, LSTMHiddenSize_2)
predictor = predictor.to(device)

# Print your neural network structure
print(predictor)

optimizer = optim.SGD(predictor.parameters(), lr=0.01)
# Out:
# GrandPredictor(
#   (lstm1): LSTMCell(4, 16)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (lstm2): LSTMCell(16, 16)
#   (FCout): Linear(in_features=16, out_features=4, bias=True)
# )

# %%
ckpt_dir = os.path.join(gdrive_root, 'Project/checkpoints')

if not os.path.exists(ckpt_dir):
  os.makedirs(ckpt_dir)
  
best_acc = 0.

ckpt_path = os.path.join(ckpt_dir, 'KOSPI_1.pt')
if os.path.exists(ckpt_path):
  ckpt = torch.load(ckpt_path)
  try:
    predictor.load_state_dict(ckpt['predictor'])
    optimizer.load_state_dict(ckpt['optimizer'])
  except RuntimeError as e:
      print('wrong checkpoint')
  else:    
    print('checkpoint is loaded !')

# %%
def predictorTrainer(predictor, x, futureRatio=0.5, TFRatio=0.5):
    seqLen = x.size()[0]
    output = []
    prevPrediction = None
    predictFrom = int(seqLen * futureRatio)
    
    assert predictFrom >= 1, 'No given data, no prediction.'

    for day in range(0, predictFrom):
      prevPrediction, h, c = predictor(x[day], None, None)
      output.append(prevPrediction.clone())
    
    for day in range(predictFrom, seqLen):
      if random.uniform(0, 1) > TFRatio:
        # No Teach forcing.
        prevPrediction, h, c = predictor(prevPrediction, h, c)
      else:
        # Yes, Teach forcing.
        prevPrediction, h, c = predictor(x[day], h, c)
      
      output.append(prevPrediction.clone())

    return torch.stack(output)

# %%
maxEpoch = 1
seqLen = 20

# %%
# Training process

it = 0
predictor.train()

losses = []
prices = []

for epoch in range(maxEpoch):
  reader = getInputData(DATA_PATH, seqLen, batchSize)
  predictor.train()
  for data in reader:
    optimizer.zero_grad()
    it = it + 1
    data = data.to(device);
    esti = predictorTrainer(predictor, data.detach(), 1, 0)
    loss = F.mse_loss(esti, data)
    
    loss.backward()
    torch.nn.utils.clip_grad_norm_(predictor.parameters(), 2)
    optimizer.step()
    losses.append(loss.item())

plt.figure(figsize=(30, 6))
plt.plot(losses, label='train loss')
plt.show()

# %%
ckpt_dir = os.path.join(gdrive_root, 'Project/checkpoints/')
ckpt_path = os.path.join(ckpt_dir, 'KOSPI_1.pt')
ckpt = {'predictor':predictor.state_dict(),
        'optimizer':optimizer.state_dict()}
torch.save(ckpt, ckpt_path)

# %%
def testDataLoader(theFile):
  reader = pd.read_csv(theFile, sep=',', chunksize=1, usecols=UsingCols)
  for chunk in reader:
    yield torch.Tensor(chunk.to_numpy())

# %%
from google.colab import widgets

showCol = 0

def drawStepFig(trueCnt, estiCnt, grid):
  predictor.eval()

  trueData = []
  trueVals = []
  estiVals = []
  reader = testDataLoader(DATA_PATH)

  h = None
  c = None

  trueLen = 0
  fullLen = trueCnt + estiCnt
  dayCnt = 0

  for data in reader:
    h = None
    c = None

    dayCnt = dayCnt + 1

    data = data.to(device)
    trueVals.append(data[0][showCol].item())
    trueData.append(data)
    trueLen = trueLen + 1

    if trueLen > fullLen:
      trueVals.pop(0)
      trueData.pop(0)
      trueLen = trueLen - 1
    if trueLen < fullLen:
      continue
    
    for day in range(trueCnt):
      estiData, h, c = predictor(trueData[day], h, c)

    estiVals.clear()
    for day in range(estiCnt - 1):
      estiVals.append(estiData[0][showCol].item())
      estiData, h, c = predictor(estiData, h, c)
    estiVals.append(estiData[0][showCol].item())

    startDay = max(0, dayCnt - (fullLen))
    endDay = max(dayCnt, fullLen)
    xAxis = [i for i in range(startDay, endDay)]
    
    if dayCnt % 100 == 0:
      with grid.output_to(0, 0):
        plt.figure(figsize=(30, 6))
        plt.plot(xAxis, trueVals + [None for i in range(fullLen - trueLen)], '-r')
        plt.plot(xAxis, [None for i in range(trueCnt)] + estiVals, '-b')
        #plt.plot(xAxis, [0 for i in range(fullLen)], ':g')
        #plt.ylim(0.9, 1.1)
        plt.show()

grid = widgets.Grid(1, 1)
drawStepFig(16, 4, grid);
# Out:
# <style>
#        table#id32, #id32 > tbody > tr > th, #id32 > tbody > tr > td {
#          border: 1px solid lightgray;
#          border-collapse:collapse;
#
#         }</style>
# <table id=id32><tr><td id=id32-0-0></td></tr></table>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-355-a2d5f0b01500> in <module>()
#      59
#      60 grid = widgets.Grid(1, 1)
# ---> 61 drawStepFig(16, 4, grid);
#
# <ipython-input-355-a2d5f0b01500> in drawStepFig(trueCnt, estiCnt, grid)
#      37
#      38     for day in range(trueCnt):
# ---> 39       estiData, h, c = predictor(trueData[day], h, c)
#      40
#      41     estiVals.clear()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-344-1a0c7a92724c> in forward(self, x, h, c)
#      19     c1, c2 = c
#      20
# ---> 21     h1, c1 = self.lstm1(x, (h1, c1))
#      22     h1 = self.dropout(h1)
#      23     h2, c2 = self.lstm2(h1, (h2, c2))
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     938             zeros = torch.zeros(input.size(0), self.hidden_size, dtype=input.dtype, device=input.device)
#     939             hx = (zeros, zeros)
# --> 940         self.check_forward_hidden(input, hx[0], '[0]')
#     941         self.check_forward_hidden(input, hx[1], '[1]')
#     942         return _VF.lstm_cell(
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in check_forward_hidden(self, input, hx, hidden_label)
#     767             raise RuntimeError(
#     768                 "Input batch size {} doesn't match hidden{} batch size {}".format(
# --> 769                     input.size(0), hidden_label, hx.size(0)))
#     770
#     771         if hx.size(1) != self.hidden_size:
#
# RuntimeError: Input batch size 1 doesn't match hidden[0] batch size 16

# %%
import plotly
